# %%
import tensorflow as tf
import h5py
import numpy as np
import os
import sys
import datetime
import time
import matplotlib.pyplot as plt

# %%
data=h5py.File('data/data.h5','r')

# %% [markdown]
# EDA

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.imshow(data['train_img'][0][:,:,0])
plt.subplot(2,2,2)
plt.imshow(data['train_img'][0][:,:,1])
plt.subplot(2,2,3)
plt.imshow(data['train_img'][0][:,:,2])
plt.subplot(2,2,4)
plt.imshow(data['train_img'][0][:,:,3])
plt.show()

# %% [markdown]
# model creation

# %%
tf.reset_default_graph()
tf.set_random_seed(1)
np.random.seed(1)
tf.config.set_memory_growth(tf.config.list_physical_devices('GPU')[0], True)

# %%
model=tf.keras.models.Sequential()
model.add(tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 4)))
model.add(tf.keras.layers.MaxPooling2D((2, 2)))
model.add(tf.keras.layers.Conv2D(64, (3, 3), activation='relu'))
model.add(tf.keras.layers.MaxPooling2D((2, 2)))
model.add(tf.keras.layers.Conv2D(64, (3, 3), activation='relu'))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(64, activation='relu'))
model.add(tf.keras.layers.Dense(1, activation='relu'))

# %%
tf.keras.utils.plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True, rankdir='TB', expand_nested=False, dpi=96)
